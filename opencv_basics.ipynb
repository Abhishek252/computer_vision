# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek252/computer_vision/blob/main/opencv_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Abhishek252/computer_vision.git
# %cd computer_vision

# %%
pwd
# Out:
# '/content/computer_vision/computer_vision'

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
import numpy as np

# %%
 image = cv2.imread('./img/GREECE.jpg')

# %%
# cv2_imshow(image)
image.shape
# Out:
# (480, 640, 3)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)

# %%
#hsv image
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
cv2_imshow(hsv)

# %%
# Edge detection
canny_img = cv2.Canny(gray, 150, 200)
cv2_imshow(canny_img)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F9A1DA78F90>

# %%
# Errosion
kernel = np.ones((5,5), np.uint8)
erode_image = cv2.erode(dilate_img, kernel, iterations=1)
cv2_imshow(erode_image)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F9A1B8B91D0>

# %%
# dilation
kerneld = np.ones((5,5), np.uint8)
dilate_img = cv2.dilate(canny_img, kerneld, iterations=1)
cv2_imshow(dilate_img)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F9A1D391CD0>

# %%
display = np.hstack((canny_img, dilate_img, erode_image))
cv2_imshow(display)
# Out:
# <PIL.Image.Image image mode=L size=1920x480 at 0x7F9A1B867910>
